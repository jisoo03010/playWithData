# %%
pip install jupyter_contrib_nbextensions && jupyter contrib
# Out:
# ...
# community-contributed spice for Jupyter Interactive Computing
#
# Subcommands
# ...
# Subcommands are launched as `jupyter contrib cmd [args]`. For information on
# using subcommand 'cmd', do: `jupyter contrib cmd -h`.
#
# nbextension
#     Install or uninstall all of jupyter_contrib_nbextensions.
# nbextensions
#     Install or uninstall all of jupyter_contrib_nbextensions.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
# ...

# %%
# !pip install selenium
# Out:
# ...
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
# %config Completer.use_jedi = False

# %%
from selenium import webdriver
driver = webdriver.Chrome('C:/Users/sdh20/Desktop/playwithdata/chromedriver.exe')
url = 'https://www.genie.co.kr/chart/top200'
driver.get(url)
from bs4 import BeautifulSoup
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# 100개의 인기차트 값 가져오기
song = soup.select('tbody > tr')

import pandas as pd

song_data =[]
rank =1
for i in song:
    title = i.select('td.info > a')[0].text.replace('\n', '').replace(' ', '')
    sing = i.select('td.info > a')[1].text
    song_data.append(['genie',rank, title, sing])
    rank = rank + 1

columns = ['서비스', '순위', '타이틀', '가수']

genieDataFrame = pd.DataFrame(song_data, columns = columns)
# Out:
# C:\Users\sdh20\AppData\Local\Temp/ipykernel_2656/2366295934.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:/Users/sdh20/Desktop/playwithdata/chromedriver.exe')

# %%
genieDataFrame.to_excel('genie.xlsx', index = True)

# %%
genieDataFrame
# Out:
#       서비스  순위                                  타이틀  \
# 0   genie   1                               TOMBOY
# 1   genie   2                         FeelMyRhythm
# 2   genie   3                   GANADARA(Feat.아이유)
# 3   genie   4                                사랑인가봐
# 4   genie   5                              사랑은늘도망가
# 5   genie   6                                듣고싶을까
# 6   genie   7                                 취중고백
# 7   genie   8                                 INVU
# 8   genie   9                           다정히내이름을부르면
# 9   genie  10                           19금abcdefu
# 10  genie  11                               언제나사랑해
# 11  genie  12                                 어제처럼
# 12  genie  13                                  신호등
# 13  genie  14                              이제나만믿어요
# 14  genie  15                                RUN2U
# 15  genie  16                                 Stay
# 16  genie  17  회전목마(Feat.Zion.T&원슈타인)(Prod.bySlom)
# ...
