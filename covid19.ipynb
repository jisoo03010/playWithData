# %%
pip install jupyter-tabnine
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arso (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ackaging (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
import pandas as pd
kto_201901 = pd.read_excel('실습데이터/kto_201901.xlsx', header =1 , usecols ='A:G', skipfooter =4)
kto_201901
# Out:
#          국적      관광     상용    공용  유학/연수      기타       계
# 0      아시아주  765082  10837  1423  14087  125521  916950
# 1        일본  198805   2233   127    785    4576  206526
# 2        대만   86393     74    22    180    1285   87954
# 3        홍콩   34653     59     2     90    1092   35896
# 4       마카오    2506      2     0     17      45    2570
# ..      ...     ...    ...   ...    ...     ...     ...
# 62  아프리카 기타     768    718    90    206     908    2690
# 63     기타대륙      33      4     0      1      16      54
# 64     국적미상      33      4     0      1      16      54
# 65     교포소계       0      0     0      0   15526   15526
# 66       교포       0      0     0      0   15526   15526
#
# [67 rows x 7 columns]

# %%
kto_201901.tail()
# Out:
#          국적   관광   상용  공용  유학/연수     기타      계
# 62  아프리카 기타  768  718  90    206    908   2690
# 63     기타대륙   33    4   0      1     16     54
# 64     국적미상   33    4   0      1     16     54
# 65     교포소계    0    0   0      0  15526  15526
# 66       교포    0    0   0      0  15526  15526

# %%
kto_201901.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국적      67 non-null     object
#  1   관광      67 non-null     int64
#  2   상용      67 non-null     int64
#  3   공용      67 non-null     int64
#  4   유학/연수   67 non-null     int64
#  5   기타      67 non-null     int64
#  6   계       67 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 3.8+ KB

# %%
kto_201901.describe()
# Out:
#                  관광            상용           공용         유학/연수             기타  \
# count      67.00000     67.000000    67.000000     67.000000      67.000000
# mean    26396.80597    408.208955   132.507463    477.462687    5564.208955
# std    102954.04969   1416.040302   474.406339   2009.484800   17209.438418
# min         0.00000      0.000000     0.000000      0.000000      16.000000
# 25%       505.00000     14.500000     2.500000     17.500000     260.000000
# 50%      1304.00000     45.000000    14.000000     43.000000     912.000000
# 75%      8365.00000    176.500000    38.000000    182.000000    2824.500000
# max    765082.00000  10837.000000  2657.000000  14087.000000  125521.000000
#
#                    계
# count      67.000000
# mean    32979.194030
# std    122821.369969
# min        54.000000
# 25%       927.000000
# 50%      2695.000000
# 75%     14905.500000
# max    916950.000000

# %%
condition = (kto_201901['관광'] == 0) \
        | (kto_201901['상용'] == 0) \
        | (kto_201901['공용'] == 0) \
        | (kto_201901['유학/연수'] == 0)
kto_201901[condition]
# Out:
#         국적    관광   상용  공용  유학/연수     기타      계
# 4      마카오  2506    2   0     17     45   2570
# 20    이스라엘   727   12   0      9     57    805
# 22  우즈베키스탄  1958  561   0    407   2828   5754
# 38     스위스   613   18   0     19     97    747
# 45     그리스   481   17   4      0    273    775
# 46    포르투갈   416   14   0     13    121    564
# 51   크로아티아   226   12   0      3    250    491
# 54     폴란드   713   10   0     27    574   1324
# 59  대양주 기타   555    3   4      0     52    614
# 63    기타대륙    33    4   0      1     16     54
# 64    국적미상    33    4   0      1     16     54
# 65    교포소계     0    0   0      0  15526  15526
# 66      교포     0    0   0      0  15526  15526

# %%
kto_201901['기준년월'] = '2019-01'

# %%
kto_201901.head()
# Out:
#      국적      관광     상용    공용  유학/연수      기타       계     기준년월
# 0  아시아주  765082  10837  1423  14087  125521  916950  2019-01
# 1    일본  198805   2233   127    785    4576  206526  2019-01
# 2    대만   86393     74    22    180    1285   87954  2019-01
# 3    홍콩   34653     59     2     90    1092   35896  2019-01
# 4   마카오    2506      2     0     17      45    2570  2019-01

# %%
kto_201901['국적'].unique()
# Out:
# array(['아시아주', '일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아',
#        '싱가포르', '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골',
#        '중국', '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미주',
#        '미국', '캐나다', '멕시코', '브라질', '미주 기타', '구주', '영국', '독일', '프랑스',
#        '네덜란드', '스웨덴', '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인',
#        '그리스', '포르투갈', '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아',
#        '불가리아', '폴란드', '구주 기타', '대양주', '오스트레일리아', '뉴질랜드', '대양주 기타',
#        '아프리카주', '남아프리카공화국', '아프리카 기타', '기타대륙', '국적미상', '교포소계', '교포'],
#       dtype=object)

# %%
continents_list = ['아시아주', '미주', '구주','대양주', '아프리카주', '기타대륙', '교포소계']
continents_list
# Out:
# ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']

# %%
condition = (kto_201901.국적.isin(continents_list) == False)
kto_201901_country = kto_201901[condition]

# %%
kto_201901_country['국적'].unique()
# Out:
# array(['일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아', '싱가포르',
#        '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골', '중국',
#        '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미국',
#        '캐나다', '멕시코', '브라질', '미주 기타', '영국', '독일', '프랑스', '네덜란드', '스웨덴',
#        '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인', '그리스', '포르투갈',
#        '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아', '불가리아', '폴란드',
#        '구주 기타', '오스트레일리아', '뉴질랜드', '대양주 기타', '남아프리카공화국', '아프리카 기타',
#        '국적미상', '교포'], dtype=object)

# %%
kto_201901_country.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월
# 1   일본  198805  2233  127    785  4576  206526  2019-01
# 2   대만   86393    74   22    180  1285   87954  2019-01
# 3   홍콩   34653    59    2     90  1092   35896  2019-01
# 4  마카오    2506     2    0     17    45    2570  2019-01
# 5   태국   34004    37  199     96  6998   41334  2019-01

# %%
kto_201901_country_newIndex = kto_201901_country.reset_index(drop= True)

# %%
kto_201901_country_newIndex
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월
# 0         일본  198805  2233   127    785   4576  206526  2019-01
# 1         대만   86393    74    22    180   1285   87954  2019-01
# 2         홍콩   34653    59     2     90   1092   35896  2019-01
# 3        마카오    2506     2     0     17     45    2570  2019-01
# 4         태국   34004    37   199     96   6998   41334  2019-01
# 5      말레이시아   19043    95     7     99   2821   22065  2019-01
# 6        필리핀   14279   211   161    184  15638   30473  2019-01
# 7      인도네시아   14183   136    38    187   4298   18842  2019-01
# 8       싱가포르    8372    94     8     48   1333    9855  2019-01
# 9        미얀마    1304    10    31     67   3877    5289  2019-01
# 10       베트남   10739   763   110   1667   6904   20183  2019-01
# 11        인도    2318  2656    46    177   3474    8671  2019-01
# 12      스리랑카     157    54     5     28   1043    1287  2019-01
# 13      파키스탄     238   178    10    193    413    1032  2019-01
# ...

# %%
contents = ['아시아'] * 25 + ['아메리카'] * 5 + ['유럽'] * 23 + ['오세아니아'] * 3 + ['아프리카'] *2 + ['기타대륙'] + ['교포']
contents
kto_201901_country_newIndex['대륙'] = contents

kto_201901_country_newIndex
# Out:
#           국적      관광    상용    공용  유학/연수     기타       계     기준년월     대륙
# 0         일본  198805  2233   127    785   4576  206526  2019-01    아시아
# 1         대만   86393    74    22    180   1285   87954  2019-01    아시아
# 2         홍콩   34653    59     2     90   1092   35896  2019-01    아시아
# 3        마카오    2506     2     0     17     45    2570  2019-01    아시아
# 4         태국   34004    37   199     96   6998   41334  2019-01    아시아
# 5      말레이시아   19043    95     7     99   2821   22065  2019-01    아시아
# 6        필리핀   14279   211   161    184  15638   30473  2019-01    아시아
# 7      인도네시아   14183   136    38    187   4298   18842  2019-01    아시아
# 8       싱가포르    8372    94     8     48   1333    9855  2019-01    아시아
# 9        미얀마    1304    10    31     67   3877    5289  2019-01    아시아
# 10       베트남   10739   763   110   1667   6904   20183  2019-01    아시아
# 11        인도    2318  2656    46    177   3474    8671  2019-01    아시아
# ...

# %%
kto_201901_country_newIndex['관광객비율(%)'] = round(kto_201901_country_newIndex['관광'] / kto_201901_country_newIndex['계'] * 100, 1)

# %%
kto_201901_country_newIndex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아      96.3
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아      98.2
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아      96.5
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아      97.5
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아      82.3

# %%
kto_201901_country_newIndex.sort_values(by ='관광객비율(%)', ascending = False).head()
# Out:
#         국적      관광    상용   공용  유학/연수    기타       계     기준년월     대륙  관광객비율(%)
# 1       대만   86393    74   22    180  1285   87954  2019-01    아시아      98.2
# 3      마카오    2506     2    0     17    45    2570  2019-01    아시아      97.5
# 2       홍콩   34653    59    2     90  1092   35896  2019-01    아시아      96.5
# 0       일본  198805  2233  127    785  4576  206526  2019-01    아시아      96.3
# 55  대양주 기타     555     3    4      0    52     614  2019-01  오세아니아      90.4

# %%
kto_201901_country_newIndex.pivot_table(values= '관광객비율(%)', 
                                        index = '대륙',
                                        aggfunc = 'mean' )
# Out:
#         관광객비율(%)
# 대륙
# 교포      0.000000
# 기타대륙   61.100000
# 아메리카   68.200000
# 아시아    59.624000
# 아프리카   32.700000
# 오세아니아  84.833333
# 유럽     63.826087

# %%
condition = kto_201901_country_newIndex['국적'] == '중국'
kto_201901_country_newIndex[condition]
# Out:
#     국적      관광    상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)
# 17  중국  320113  2993  138   8793  60777  392814  2019-01  아시아      81.5

# %%
tourist_sum = sum(kto_201901_country_newIndex['관광'])

# %%
kto_201901_country_newIndex['전체비율(%)'] = round(kto_201901_country_newIndex['관광'] / tourist_sum * 100, 1)
kto_201901_country_newIndex.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  \
# 0   일본  198805  2233  127    785  4576  206526  2019-01  아시아      96.3
# 1   대만   86393    74   22    180  1285   87954  2019-01  아시아      98.2
# 2   홍콩   34653    59    2     90  1092   35896  2019-01  아시아      96.5
# 3  마카오    2506     2    0     17    45    2570  2019-01  아시아      97.5
# 4   태국   34004    37  199     96  6998   41334  2019-01  아시아      82.3
#
#    전체비율(%)
# 0     22.5
# 1      9.8
# 2      3.9
# 3      0.3
# 4      3.8

# %%
kto_201901_country_newIndex.sort_values(by = '전체비율(%)', ascending = False).head()
# Out:
#     국적      관광    상용    공용  유학/연수     기타       계     기준년월    대륙  관광객비율(%)  \
# 17  중국  320113  2993   138   8793  60777  392814  2019-01   아시아      81.5
# 0   일본  198805  2233   127    785   4576  206526  2019-01   아시아      96.3
# 1   대만   86393    74    22    180   1285   87954  2019-01   아시아      98.2
# 25  미국   42989   418  2578    229  16523   62737  2019-01  아메리카      68.5
# 2   홍콩   34653    59     2     90   1092   35896  2019-01   아시아      96.5
#
#     전체비율(%)
# 17     36.2
# 0      22.5
# 1       9.8
# 25      4.9
# 2       3.9

# %%
# 함수를 이용하여 여러개의 엑셀 파일을 쉽게 정리하기 
def creaate_kto_data(yy, mm):
    file_path ='실습데이터/kto_{}{}.xlsx'.format(yy, mm)
    df = pd.read_excel(file_path, header= 1, skipfooter =4, usecols ='A:G')
    
    df['기준년월'] ='{}-{}'.format(yy, mm)
    
    ignore_list = ['아시아주', '미주', '구주', '대양주', '아프리카주', '기타대륙', '교포소계']
    
    condition = (df['국적'].isin(ignore_list) == False)
    df_country = df[condition].reset_index(drop=True)
    
    
    # 대륙 컬럼 추가
    contents = ['아시아'] * 25 + ['아메리카'] * 5 + ['유럽'] * 23 + ['오세아니아'] * 3 + ['아프리카'] *2 + ['기타대륙'] + ['교포']
    df_country['대륙'] = contents
    
    #국가별 관광객 비율 컬럼 추가 
    df_country['관광객비율(%)'] = round(df_country.관광 / df_country.계 * 100, 1)
    
    #전체 비율 컬럼 추가 
    tourist_sum = sum(df_country['관광'])
    df_country['전체비율(%)'] = round(df_country['관광'] / tourist_sum *  100, 1)
    
    return(df_country)

# %%
kto_test = creaate_kto_data(2018, 12)
kto_test.head()
# Out:
#     국적      관광    상용   공용  유학/연수    기타       계     기준년월   대륙  관광객비율(%)  \
# 0   일본  252461  1698  161    608  3593  258521  2018-12  아시아      97.7
# 1   대만   85697    71   22    266  1252   87308  2018-12  아시아      98.2
# 2   홍콩   58355    41    3    208   939   59546  2018-12  아시아      98.0
# 3  마카오    6766     0    1     20    36    6823  2018-12  아시아      99.2
# 4   태국   47242    42  302     58  6382   54026  2018-12  아시아      87.4
#
#    전체비율(%)
# 0     22.7
# 1      7.7
# 2      5.2
# 3      0.6
# 4      4.2

# %%
# 반복문을 통해 다수의 엑셀 데이터를 불러와서 합치기
for yy in range(2010, 2021):
    for mm in range(1, 13):
        yymm = '{}{}'.format(yy, mm)
        print(yymm)
# Out:
# 20101
# 20102
# 20103
# 20104
# 20105
# 20106
# 20107
# 20108
# 20109
# 201010
# 201011
# 201012
# 20111
# 20112
# 20113
# 20114
# 20115
# 20116
# 20117
# 20118
# 20119
# 201110
# 201111
# 201112
# 20121
# 20122
# 20123
# 20124
# 20125
# 20126
# 20127
# 20128
# 20129
# 201210
# 201211
# 201212
# 20131
# 20132
# 20133
# 20134
# 20135
# 20136
# 20137
# 20138
# 20139
# 201310
# 201311
# 201312
# 20141
# 20142
# 20143
# 20144
# 20145
# 20146
# 20147
# 20148
# 20149
# 201410
# 201411
# 201412
# 20151
# 20152
# 20153
# 20154
# 20155
# 20156
# 20157
# 20158
# 20159
# 201510
# 201511
# 201512
# 20161
# 20162
# 20163
# 20164
# 20165
# 20166
# 20167
# 20168
# 20169
# 201610
# 201611
# 201612
# 20171
# 20172
# 20173
# 20174
# 20175
# 20176
# 20177
# 20178
# 20179
# 201710
# 201711
# 201712
# 20181
# 20182
# 20183
# 20184
# 20185
# 20186
# 20187
# 20188
# 20189
# 201810
# 201811
# 201812
# 20191
# 20192
# 20193
# 20194
# 20195
# 20196
# 20197
# 20198
# 20199
# 201910
# 201911
# 201912
# 20201
# ...

# %%
mm = 1
print(mm
     )
# Out:
# 1

# %%
str(mm).zfill(2) # 두 자리 숫자로 만들어줌
# Out:
# '01'

# %%
print(str(mm).zfill(3)) # 세 자리 숫자로 만들어줌
print( str(mm).zfill(4) )# 네 자리 숫자로 만들어줌
# Out:
# 001
# 0001

# %%
for yy in range(2010, 2021):
    for mm in range(1, 13):
        mm_str = str(mm).zfill(2)
        yymm = '{}{}'.format(yy, mm_str)
        print(yymm)
# Out:
# 201001
# 201002
# 201003
# 201004
# 201005
# 201006
# 201007
# 201008
# 201009
# 201010
# 201011
# 201012
# 201101
# 201102
# 201103
# 201104
# 201105
# 201106
# 201107
# 201108
# 201109
# 201110
# 201111
# 201112
# 201201
# 201202
# 201203
# 201204
# 201205
# 201206
# 201207
# 201208
# 201209
# 201210
# 201211
# 201212
# 201301
# 201302
# 201303
# 201304
# 201305
# 201306
# 201307
# 201308
# 201309
# 201310
# 201311
# 201312
# 201401
# 201402
# 201403
# 201404
# 201405
# 201406
# 201407
# 201408
# 201409
# 201410
# 201411
# 201412
# 201501
# 201502
# 201503
# 201504
# 201505
# 201506
# 201507
# 201508
# 201509
# 201510
# 201511
# 201512
# 201601
# 201602
# 201603
# 201604
# 201605
# 201606
# 201607
# 201608
# 201609
# 201610
# 201611
# 201612
# 201701
# 201702
# 201703
# 201704
# 201705
# 201706
# 201707
# 201708
# 201709
# 201710
# 201711
# 201712
# 201801
# 201802
# 201803
# 201804
# 201805
# 201806
# 201807
# 201808
# 201809
# 201810
# 201811
# 201812
# 201901
# 201902
# 201903
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for yy in range(2010, 2021):
    for mm in range(1, 13):
        temp = creaate_kto_data(str(yy), str(mm).zfill(2))
        df = df.append(temp, ignore_index = True)
        print(df.tail())
# Out:
#             국적   관광   상용  공용  유학/연수     기타      계     기준년월     대륙  관광객비율(%)  \
# 7555    대양주 기타  730    0   4      4    168    906  2010-01  오세아니아      80.6
# 7556  남아프리카공화국  214   27   0      2    545    788  2010-01   아프리카      27.2
# 7557   아프리카 기타  349  594  25     86    296   1350  2010-01   아프리카      25.9
# 7558      국적미상   10    3   0      0      0     13  2010-01   기타대륙      76.9
# 7559        교포    0    0   0      0  22537  22537  2010-01     교포       0.0
#
#       전체비율(%)
# 7555      0.2
# 7556      0.1
# 7557      0.1
# 7558      0.0
# 7559      0.0
#             국적   관광   상용  공용  유학/연수     기타      계     기준년월     대륙  관광객비율(%)  \
# 7615    대양주 기타  264    0   0      5    140    409  2010-02  오세아니아      64.5
# 7616  남아프리카공화국  278   24   0      2    572    876  2010-02   아프리카      31.7
# 7617   아프리카 기타  413  588  25    147    301   1474  2010-02   아프리카      28.0
# 7618      국적미상    6    0   0      1      3     10  2010-02   기타대륙      60.0
# ...

# %%
df = pd.DataFrame()

#패턴 분석결과를 이중 반복문을 통해 구현 
for yy in range(2010, 2021):
    for mm in range(1, 13):
        try:
            temp  = creaate_kto_data(str(yy), str(mm).zfill(2))
            df= df.append(temp, ignore_index = True)
        except:
            pass

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   국적        7500 non-null   object
#  1   관광        7500 non-null   int64
#  2   상용        7500 non-null   int64
#  3   공용        7500 non-null   int64
#  4   유학/연수     7500 non-null   int64
#  5   기타        7500 non-null   int64
#  6   계         7500 non-null   int64
#  7   기준년월      7500 non-null   object
#  8   대륙        7500 non-null   object
#  9   관광객비율(%)  7500 non-null   float64
#  10  전체비율(%)   7500 non-null   float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 644.7+ KB

# %%
# 통합 데이터를 엑셀 파일로 저장하기
df.to_excel('./kto_total.xlsx', index = False)

# %%
condition= (df['국적'] == '중국')
df_filter = df[condition]
df_filter.head()
# Out:
#      국적     관광     상용   공용  유학/연수     기타       계     기준년월   대륙  관광객비율(%)  \
# 17   중국  40425  11930   55   2751  36091   91252  2010-01  아시아      44.3
# 77   중국  60590   7907   68  29546  42460  140571  2010-02  아시아      43.1
# 137  중국  50330  13549  174  14924  62480  141457  2010-03  아시아      35.6
# 197  중국  84252  13306  212   2199  47711  147680  2010-04  아시아      57.1
# 257  중국  89056  12325  360   2931  49394  154066  2010-05  아시아      57.8
#
#      전체비율(%)
# 17      10.1
# 77      13.6
# 137      9.2
# 197     15.5
# 257     17.0

# %%
file_path = './[국적별 관광객 데이터] 중국.xlsx'
df_filter.to_excel(file_path, index = False)

# %%
cntry_list = df['국적'].unique()
cntry_list
# Out:
# array(['일본', '대만', '홍콩', '마카오', '태국', '말레이시아', '필리핀', '인도네시아', '싱가포르',
#        '미얀마', '베트남', '인도', '스리랑카', '파키스탄', '방글라데시', '캄보디아', '몽골', '중국',
#        '이란', '이스라엘', '터키', '우즈베키스탄', '카자흐스탄', 'GCC', '아시아 기타', '미국',
#        '캐나다', '멕시코', '브라질', '미주 기타', '영국', '독일', '프랑스', '네덜란드', '스웨덴',
#        '스위스', '이탈리아', '덴마크', '노르웨이', '벨기에', '오스트리아', '스페인', '그리스', '포르투갈',
#        '핀란드', '아일랜드', '우크라이나', '러시아', '크로아티아', '루마니아', '불가리아', '폴란드',
#        '구주 기타', '오스트레일리아', '뉴질랜드', '대양주 기타', '남아프리카공화국', '아프리카 기타',
#        '국적미상', '교포'], dtype=object)

# %%
len(cntry_list)
# 개별 국적별 관광객 데이터 저장하기'
for cntry in cntry_list:
    # 국적으로 필터링하기
    condition = (df['국적'] == cntry)
    df_filter = df[condition]
    
    #국적명을 반영한 파일명 만들기 저장하기
    file_path = './[국적별 관광객 데이터] {}.xlsx'.format(cntry)
    
    #정해 놓은 파일명으로 저장하기
    df_filter.to_excel(file_path, index = False)

# %%
word_list = ['오메가3', 'None', '비타민c500', 'None', '홍삼절편']
result = []

# %%
for word in word_list:
    if word != 'None':
        result.append(word)
    else:
        result.append('')

# %%
result
# Out:
# ['오메가3', '', '비타민c500', '', '홍삼절편']

# %%
# 시각화 .. 
import pandas as pd
df = pd.read_excel('./kto_total.xlsx')
df
# Out:
#             국적      관광    상용  공용  유학/연수    기타       계     기준년월     대륙  \
# 0           일본  202825  1750  89    549  3971  209184  2010-01    아시아
# 1           대만   35788    41  17     37   516   36399  2010-01    아시아
# 2           홍콩   13874    55   0     21   595   14545  2010-01    아시아
# 3          마카오     554     0   0      0     0     554  2010-01    아시아
# 4           태국   13374    39  13     53  4335   17814  2010-01    아시아
# ...        ...     ...   ...  ..    ...   ...     ...      ...    ...
# 7495    대양주 기타       1     0   1      0     3       5  2020-05  오세아니아
# 7496  남아프리카공화국       1     0   3      0    25      29  2020-05   아프리카
# 7497   아프리카 기타       3     1   3      6   118     131  2020-05   아프리카
# 7498      국적미상       1     0   0      0     3       4  2020-05   기타대륙
# 7499        교포       0     0   0      0   790     790  2020-05     교포
#
#       관광객비율(%)  전체비율(%)
# 0         97.0     50.6
# 1         98.3      8.9
# 2         95.4      3.5
# 3        100.0      0.1
# ...

# %%
# 글꼴 변경하기 위한 
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
    path = "C:/Windows/Fonts/H2GTRM.TTF"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family = font_name)
elif platform.system() == 'Darwin':
    rf('font', family = 'AppleGothic')
else:
    print('Check your OS systems')

# %%
import matplotlib.pyplot as plt # 가장 기본적인 시각화 라이브러리이다.

condition = (df['국적'] == '중국')

df_filter = df[condition]
df_filter.head()

plt.plot(df_filter['기준년월'], df_filter['관광'])
# plt.plot함수의 첫 번째 값에는 그래프의 X축에 지정할 칼럼을 , 두 번째 값에는 Y 축에 지정할 컬럼을 지정한다.
# df_filter 데이터의 기준년월이 x축 관광데이터가 Y축에 들어간 결과가 된다.
plt.show()

#단점 x축 값들ㅇ은 너무 많은 값이 겹쳐져서 알아보기가 힘들다.
#보완해서 시계열 그래프를 그려보자~~

# %%
# 그래프 크기 조절
plt.figure(figsize = (12, 4)) # 가로 12인치 세로 4인치

#그래프 내용 설정
plt.plot(df_filter['기준년월'], df_filter['관광'])

#그래프의 타이틀 x축 y축 이름 달기
plt.title('중국 국적의 관광객 추이')
plt.xlabel('기준년월')
plt.ylabel('관광객수')

# x축 눈금 값을 설정
plt.xticks(['2010-01', '2011-01', '2012-01', '2013-01', '2014-01', '2015-01','2016-01', '2017-01', '2018-01', '2019-01',  '2020-01'])

#그래프 표현하기 
plt.show()

# %%
cntry_list = ['중국', '일본', '대만', '미국', '홍콩']
# Out:
# ['중국', '일본', '대만', '미국', '홍콩']

# %%
for cntry in cntry_list:
    condition = (df['국적'] == cntry)
    df_filter = df[condition]
    df_filter.head()
    plt.plot(df_filter['기준년월'], df_filter['관광'])
# plt.plot함수의 첫 번째 값에는 그래프의 X축에 지정할 칼럼을 , 두 번째 값에는 Y 축에 지정할 컬럼을 지정한다.
# df_filter 데이터의 기준년월이 x축 관광데이터가 Y축에 들어간 결과가 된다.
plt.show()
